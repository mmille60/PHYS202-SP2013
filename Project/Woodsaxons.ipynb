# %%
def Woodsaxson(atom):
    p_r=lambda r: p0*(1+(w*r**2)/R0)/(1+exp((r-R0)/a))
    p0=1
    if atom=='O' or atom ==16:
        w=-0.051
        R0=2.608
        a=.513
    elif atom=='C' or atom==12:
        w=0.
        R0=2.47
        a=0.
    elif atom=='Al' or atom==27:
        R0=3.07
        a=.519
        w=0.
    elif atom=='S' or atom==32:
        R0=3.458
        a=.61
        w=0
    elif atom=="Ca" or atom==40:
        w=-0.161
        R0=3.76
        a=.586
    elif atom=='Ni' or atom==58:
        R0=4.309
        a=.516
        w=-0.1308
    elif atom=='Cu' or atom==63:
        R0=4.2
        a=.596
        w=0
    elif atom=='W' or atom==186:
        R0=6.51
        a=.535
        w=0
    elif atom=='Au' or atom==197:
        R0=6.38
        a=.535
        w=0
    elif atom=='Pb' or atom==208:
        R0=6.68
        a=.546
        w=0
    elif atom=='U' or atom==238:
        R0=6.68
        a=.6
        w=0
    r=np.arange(0,2*R0,.01)
    return p_r(r)

# %%
def Woodsaxson_for_R(atom):
    p_r=lambda r: p0*(1+(w*r**2)/R0)/(1+exp((r-R0)/a))
    p0=1
    if atom=='O' or atom ==16:
        w=-0.051
        R0=2.608
        a=.513
    elif atom=='C' or atom==12:
        w=0.
        R0=2.47
        a=0.
    elif atom=='Al' or atom==27:
        R0=3.07
        a=.519
        w=0.
    elif atom=='S' or atom==32:
        R0=3.458
        a=.61
        w=0
    elif atom=="Ca" or atom==40:
        w=-0.161
        R0=3.76
        a=.586
    elif atom=='Ni' or atom==58:
        R0=4.309
        a=.516
        w=-0.1308
    elif atom=='Cu' or atom==63:
        R0=4.2
        a=.596
        w=0
    elif atom=='W' or atom==186:
        R0=6.51
        a=.535
        w=0
    elif atom=='Au' or atom==197:
        R0=6.38
        a=.535
        w=0
    elif atom=='Pb' or atom==208:
        R0=6.68
        a=.546
        w=0
    elif atom=='U' or atom==238:
        R0=6.68
        a=.6
        w=0
    r=np.arange(0,2*R0,.01)
    return r

# %%
rO=np.arange(0,2*2.608,.01)
plot(rO,Woodsaxson("O"),label="oxygen dencity plot")
rCu=np.arange(0,2*4.2,.01)
plot(rCu,Woodsaxson("Cu"),label="copper dencity plot")
rPb=np.arange(0,2*6.68,.01)
plot(rPb,Woodsaxson("Pb"),label="lead dencity plot")
legend(loc="best")
xlabel('radius(fm)')
ylabel('dencity')
show()

# %%
def random_r(number,atom):
    N=number
    z=numpy.random.random_sample(N);
    F1=cumsum(Woodsaxson(atom))
    a=sum(Woodsaxson(atom))
    F1=F1/a
    T=F1.searchsorted(z)
    r=Woodsaxson_for_R(atom)
    new=r[T]
    return new

# %%
hist(random_r(1000,"O"),50,normed=True,label="Sampled Distribution")
show()

# %%
def random_r_and_theta(number,atom):
    import random
    import numpy as np
    N=number
    z=numpy.random.random_sample(N);
    F1=cumsum(Woodsaxson(atom))
    a=sum(Woodsaxson(atom))
    F1=F1/a
    T=F1.searchsorted(z)
    r=Woodsaxson_for_R(atom)
    new=r[T]
    theta=zeros(len(new))
    t=0
    for i in range(0,len(new)):
        theta[t]=random.uniform(0,2*pi)
        t+=1
    return (theta,new)

# %%
r=random_r_and_theta(32,"O")[1]
theta=random_r_and_theta(32,"Pb")[0]
print r
print theta
# Out:
# [ 1.69  0.68  0.41  1.13  1.94  1.39  2.72  1.23  0.91  2.58  1.21  0.92
#   1.66  1.35  1.67  0.28  3.91  2.32  1.77  1.95  2.3   1.    2.32  0.87
#   0.51  0.85  1.19  1.95  2.91  0.83  3.34  1.55]
# [ 1.99962847  1.49351672  4.97915348  5.02366391  6.09160232  5.58403171
#   4.5242712   2.90329008  2.1489796   1.6288947   0.88181607  4.00407603
#   5.60091581  6.26694503  3.31520609  4.22049006  4.09346457  4.432018
#   2.68657151  2.81706893  2.90270111  5.16600066  2.15925945  2.79768492
#   4.92554174  0.09620421  4.99305382  4.98051311  0.42824522  3.60534071
#   2.23674054  4.95335746]

# %%
import matplotlib
import numpy as np
from matplotlib.pyplot import figure, show, rc, grid

# radar green, solid grid lines
rc('grid', color='#316931', linewidth=1, linestyle='-')
rc('xtick', labelsize=15)
rc('ytick', labelsize=15)

# force square figure and square axes looks better for polar, IMO
width, height = matplotlib.rcParams['figure.figsize']
size = min(width, height)
# make a square figure
fig = figure(figsize=(size, size))
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], polar=True, axisbg='#d5de9c')

r=random_r_and_theta(416,"Pb")[1]
theta=random_r_and_theta(416,"Pb")[0]
ax.plot(theta,r,"r*", lw=10,markersize=15)
ax.set_rmax(4)
grid(True)

show()
