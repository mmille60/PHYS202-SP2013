# %%
data = loadtxt("rpp2012.txt",str)
x = data[:,1]
y = data[:,4]
yee = data[:,5]
xee = data[:,7]
plab=zeros(len(x))#GEV/c
sig=zeros(len(y))#MB
plaberr=zeros(len(x))
sigerr=zeros(len(y))
for i in range(0,len(x)):
    plab[i]=float(x[i])
    sig[i]=float(y[i])
    plaberr[i]=float(xee[i])
    sigerr[i]=float(yee[i])

# %%
data = loadtxt("rpp2012-pp_elastic.txt",str)
xe = data[:,1]
ye = data[:,4]
yeel = data[:,5]
xeel = data[:,7]
plab_elas=zeros(len(xe))#GEV/c
sig_elas=zeros(len(ye))#MB
elaplaberr=zeros(len(xe))
elasigerr=zeros(len(ye))
for i in range(0,len(xe)):
    plab_elas[i]=float(xe[i])
    sig_elas[i]=float(ye[i])
    elaplaberr[i]=float(xeel[i])
    elasigerr[i]=float(yeel[i])
from scipy.interpolate import interp1d
#newsig = interp1d(plab_elas,sig_elas)(10**4)#interpulates temp and resistance values
#print newsig

# %%
figure(figsize=(10,7))
ax = gca()
scatter(plab,sig,s=.8)
scatter(plab_elas,sig_elas,color="green",s=.8)
ax.set_xscale('log')
ax.set_yscale('log')
#loglog(plab,sig)
#loglog(plab_elas,sig_elas)
ax.scatter
ylim(0,350)
ylabel("Cross section(mb)",fontsize=18)
xlabel(r"$P_{lab}(\frac{Gev}{c})$",fontsize=18)
errorbar(plab,sig,xerr=plaberr,yerr=sigerr)
errorbar(plab_elas,sig_elas,xerr=elaplaberr,yerr=elasigerr)
ax.annotate("$total$",xy=(300,50),fontsize=14)
ax.annotate("$pp$",xy=(70,20),fontsize=14)
ax.annotate("$elastic$",xy=(200,10),fontsize=14)
ax.annotate(r"$P_{lab}(\frac{Gev}{c})$",xy=(10**7,7),fontsize=25)
grid(True)

show()

# %%
from scipy.optimize import curve_fit
def func(x, a, b, c):
   return a*exp(-b*x) + c

x = linspace(0,4,50)
y = func(x, 2.5, 1.3, 0.5)
yn = y + 0.2*random.normal(size=len(x))
popt, pcov = curve_fit(func, x, yn)
print popt
errorbar(x,y,yn-y,0,'r.') 
plot(x,func(x,popt[0],popt[1],popt[2]))
show()


#Make an array with one more x value
xex = zeros(len(x)+1,float)
xex[0:-1] = x.copy()
xex[-1] = 6.

plot(xex,func(xex,popt[0],popt[1],popt[2]))
errorbar(x,y,yn-y,0,'r.')
# Out:
# [ 2.67644119  1.46141454  0.54082699]
# <Container object of 3 artists>

# %%
from scipy.optimize import curve_fit
def func(s,Z,B,Y,Y2):
    sig=Z+B*(log(s/sM))**2+Y*(sM/s)**n1-Y2*(sM/s)**n2
    return sig
hb=6.626*10**-34
c=3*10**8
n1=.462
n2=.550
M=2.15
ma=1.67*10**-27
mb=1.67*10**-27
Z=pi*(hb*c)**2/M**2
B=pi*(hb*c)**2/M**2
sM=(ma+mb+M)**2
Y=12.72
Y2=7.35
s = linspace(0,10**5,100.)
y = func(s,Z,B,Y,Y2)
yn = y + 0.2*random.normal(size=len(s))
popt, pcov = curve_fit(func, s, yn)
print popt
errorbar(s,y,yn-y,0,'r.') 
plot(s,func(x,popt[0],popt[1],popt[2]))
show()


#Make an array with one more x value
xex = zeros(len(s)+1,float)
xex[0:-1] = s.copy()
xex[-1] = 6.

plot(xex,func(xex,popt[0],popt[1],popt[2]))
errorbar(s,y,yn-y,0,'r.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-f06e79dfd30f> in <module>()
#      18 y = func(s,Z,B,Y,Y2)
#      19 yn = y + 0.2*random.normal(size=len(s))
# ---> 20 popt, pcov = curve_fit(func, s, yn)
#      21 print popt
#      22 errorbar(s,y,yn-y,0,'r.')
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, **kw)
#     432     # Remove full_output from kw, otherwise we're passing it in twice.
#     433     return_full = kw.pop('full_output', False)
# --> 434     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     435     (popt, pcov, infodict, errmsg, ier) = res
#     436
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     336             R = dot(r, perm)
#     337             try:
# --> 338                 cov_x = inv(dot(transpose(R),R))
#     339             except LinAlgError:
#     340                 pass
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a)
#     285
#     286     """
# --> 287     a1 = np.asarray_chkfinite(a)
#     288     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     289         raise ValueError('expected square matrix')
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a)
#     588            and (_nx.isnan(a).any() or _nx.isinf(a).any()):
#     589         raise ValueError(
# --> 590                 "array must not contain infs or NaNs")
#     591     return a
#     592
#
# ValueError: array must not contain infs or NaNs

# %%
from scipy.optimize import curve_fit
def func(s):
    hb=6.626*10**-34
    c=3*10**8
    n1=.462
    n2=.550
    M=2.15
    ma=1.67*10**-27
    mb=1.67*10**-27
    Z=pi*(hb*c)**2/M**2
    B=pi*(hb*c)**2/M**2
    sM=(ma+mb+M)**2
    Y=12.72
    Y2=7.35
    sig=Z+B*(log(s/sM))**2+Y*(sM/s)**n1-Y2*(sM/s)**n2
    return sig

s = linspace(0,10**5,100.)
D=func(s)
plot(s,D)
